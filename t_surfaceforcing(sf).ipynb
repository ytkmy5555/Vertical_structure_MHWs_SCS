# %%
import numpy as np

# %%
data1 = np.load('./Qnet_93_20_1_12_degree_chahi.npz')
data1.files
# Out:
# ['ulwrf', 'dlwrf', 'dswrf', 'uswrf', 'shtfl', 'lhtfl']

# %%
dlwrf = data1['dlwrf'][:]
dswrf = data1['dswrf'][:]
ulwrf = data1['ulwrf'][:]
uswrf = data1['uswrf'][:]
lhtfl = data1['lhtfl'][:]
shtfl = data1['shtfl'][:]
dlwrf.shape
# Out:
# (10227, 241, 241)

# %%
dlwrf
# Out:
# array([[[296.69884418, 298.64607563, 300.55210459, ..., 388.35861996,
#          388.90021868, 389.47462389],
#         [297.85037737, 299.73829167, 301.58944744, ..., 388.7603587 ,
#          389.31748632, 389.90564389],
#         [298.98011172, 300.81203033, 302.61117569, ..., 389.15717263,
#          389.72933752, 390.33085867],
#         ...,
#         [377.89272401, 379.4127738 , 380.863708  , ..., 419.7494087 ,
#          419.48870834, 419.2062338 ],
#         [377.37015688, 378.88088587, 380.32574544, ..., 418.5480675 ,
#          418.28089658, 417.9927783 ],
#         [376.86357093, 378.36352157, 379.80105996, ..., 417.31069798,
#          417.03836887, 416.7460553 ]],
#
#        [[317.45159939, 318.33023231, 319.30195026, ..., 407.77882584,
#          407.84662337, 407.88419912],
#         [319.90733083, 320.73622907, 321.66103416, ..., 407.94970082,
#          408.04261452, 408.10307141],
#         [322.24383088, 323.02689167, 323.90824451, ..., 408.09572177,
# ...

# %%
dlwrf_new = dlwrf[:10227,:,:]
dswrf_new = dswrf[:10227,:,:]
ulwrf_new = ulwrf[:10227,:,:]
uswrf_new = uswrf[:10227,:,:]
lhtfl_new = lhtfl[:10227,:,:]
shtfl_new = shtfl[:10227,:,:]

# %%
dlwrf_new1 = dlwrf_new[1281:1297]
dlwrf_new2 = dlwrf_new[1743:1750]
dlwrf_new3 = dlwrf_new[1755:1762]
dlwrf_new4 = dlwrf_new[1788:1805]
dlwrf_new5 = dlwrf_new[1819:1851]
dlwrf_new6 = dlwrf_new[1867:1929]
dlwrf_new7 = dlwrf_new[1945:1950]
dlwrf_new8 = dlwrf_new[1955:1971]
dlwrf_new9 = dlwrf_new[1987:2004]
dlwrf_new10 = dlwrf_new[2019:2118]
dlwrf_new11 = dlwrf_new[2133:2150]
dlwrf_new12 = dlwrf_new[2158:2169]
dlwrf_new13 = dlwrf_new[2179:2227]
dlwrf_new14 = dlwrf_new[2267:2279]
dlwrf_new15 = dlwrf_new[2298:2303]
dlwrf_new16 = dlwrf_new[2566:2571]
dlwrf_new17 = dlwrf_new[2668:2683]
dlwrf_new18 = dlwrf_new[2941:2950]
dlwrf_new19 = dlwrf_new[2953:2959]
dlwrf_new20 = dlwrf_new[3000:3008]
dlwrf_new21 = dlwrf_new[3014:3024]
dlwrf_new22 = dlwrf_new[3028:3036]
dlwrf_new23 = dlwrf_new[3039:3053]
dlwrf_new24 = dlwrf_new[3220:3225]
dlwrf_new25 = dlwrf_new[3228:3233]
dlwrf_new26 = dlwrf_new[3418:3428]
dlwrf_new27 = dlwrf_new[3461:3471]
dlwrf_new28 = dlwrf_new[3584:3595]
dlwrf_new92 = dlwrf_new[10210:10215]

# %%
dswrf_new1 = dswrf_new[1281:1297]
dswrf_new2 = dswrf_new[1743:1750]
dswrf_new3 = dswrf_new[1755:1762]
dswrf_new4 = dswrf_new[1788:1805]
dswrf_new5 = dswrf_new[1819:1851]
dswrf_new6 = dswrf_new[1867:1929]
dswrf_new7 = dswrf_new[1945:1950]
dswrf_new8 = dswrf_new[1955:1971]
dswrf_new9 = dswrf_new[1987:2004]
dswrf_new10 = dswrf_new[2019:2118]
dswrf_new11 = dswrf_new[2133:2150]
dswrf_new12 = dswrf_new[2158:2169]
dswrf_new13 = dswrf_new[2179:2227]
dswrf_new14 = dswrf_new[2267:2279]
dswrf_new15 = dswrf_new[2298:2303]
dswrf_new16 = dswrf_new[2566:2571]
dswrf_new17 = dswrf_new[2668:2683]
dswrf_new18 = dswrf_new[2941:2950]
dswrf_new19 = dswrf_new[2953:2959]
dswrf_new20 = dswrf_new[3000:3008]
dswrf_new21 = dswrf_new[3014:3024]
dswrf_new22 = dswrf_new[3028:3036]
dswrf_new23 = dswrf_new[3039:3053]
dswrf_new24 = dswrf_new[3220:3225]
dswrf_new25 = dswrf_new[3228:3233]
dswrf_new26 = dswrf_new[3418:3428]
dswrf_new27 = dswrf_new[3461:3471]
dswrf_new28 = dswrf_new[3584:3595]
dswrf_new29 = dswrf_new[3604:3609]
dswrf_new30 = dswrf_new[3625:3630]
dswrf_new31 = dswrf_new[3635:3657]
dswrf_new32 = dswrf_new[4517:4522]
dswrf_new33 = dswrf_new[4575:4581]
dswrf_new34 = dswrf_new[4695:4703]
dswrf_new35 = dswrf_new[4873:4879]
dswrf_new36 = dswrf_new[5069:5093]
dswrf_new37 = dswrf_new[5163:5169]
dswrf_new38 = dswrf_new[5266:5292]
dswrf_new39 = dswrf_new[5314:5328]
dswrf_new40 = dswrf_new[5769:5793]
dswrf_new41 = dswrf_new[5898:5903]
dswrf_new42 = dswrf_new[5906:5912]
dswrf_new43 = dswrf_new[5923:5928]
dswrf_new44 = dswrf_new[6240:6254]
dswrf_new45 = dswrf_new[6263:6277]
dswrf_new46 = dswrf_new[6345:6361]
dswrf_new47 = dswrf_new[6370:6413]
dswrf_new48 = dswrf_new[6422:6450]
dswrf_new49 = dswrf_new[6472:6501]
dswrf_new50 = dswrf_new[7002:7008]
dswrf_new51 = dswrf_new[7015:7022]
dswrf_new52 = dswrf_new[7044:7076]
dswrf_new53 = dswrf_new[7264:7305]
dswrf_new54 = dswrf_new[7309:7314]
dswrf_new55 = dswrf_new[7385:7401]
dswrf_new56 = dswrf_new[7432:7477]
dswrf_new57 = dswrf_new[7494:7499]
dswrf_new58 = dswrf_new[7784:7795]
dswrf_new59 = dswrf_new[7799:7835]
dswrf_new60 = dswrf_new[7851:7860]
dswrf_new61 = dswrf_new[7901:7909]
dswrf_new62 = dswrf_new[7912:7917]
dswrf_new63 = dswrf_new[7998:8011]
dswrf_new64 = dswrf_new[8161:8210]
dswrf_new65 = dswrf_new[8243:8253]
dswrf_new66 = dswrf_new[8260:8268]
dswrf_new67 = dswrf_new[8278:8324]
dswrf_new68 = dswrf_new[8342:8431]
dswrf_new69 = dswrf_new[8512:8592]
dswrf_new70 = dswrf_new[8595:8626]
dswrf_new71 = dswrf_new[8636:8648]
dswrf_new72 = dswrf_new[8719:8762]
dswrf_new73 = dswrf_new[8769:8788]
dswrf_new74 = dswrf_new[8893:8900]
dswrf_new75 = dswrf_new[8988:9000]
dswrf_new76 = dswrf_new[9029:9057]
dswrf_new77 = dswrf_new[9086:9108]
dswrf_new78 = dswrf_new[9191:9196]
dswrf_new79 = dswrf_new[9266:9288]
dswrf_new80 = dswrf_new[9465:9514]
dswrf_new81 = dswrf_new[9544:9549]
dswrf_new82 = dswrf_new[9553:9566]
dswrf_new83 = dswrf_new[9591:9618]
dswrf_new84 = dswrf_new[9629:9677]
dswrf_new85 = dswrf_new[9770:9783]
dswrf_new86 = dswrf_new[9789:9807]
dswrf_new87 = dswrf_new[9867:9877]
dswrf_new88 = dswrf_new[9885:9891]
dswrf_new89 = dswrf_new[9940:9957]
dswrf_new90 = dswrf_new[9987:10154]
dswrf_new91 = dswrf_new[10188:10195]
dswrf_new92 = dswrf_new[10210:10215]

# %%
uswrf_new1 = uswrf_new[1281:1297]
uswrf_new2 = uswrf_new[1743:1750]
uswrf_new3 = uswrf_new[1755:1762]
uswrf_new4 = uswrf_new[1788:1805]
uswrf_new5 = uswrf_new[1819:1851]
uswrf_new6 = uswrf_new[1867:1929]
uswrf_new7 = uswrf_new[1945:1950]
uswrf_new8 = uswrf_new[1955:1971]
uswrf_new9 = uswrf_new[1987:2004]
uswrf_new10 = uswrf_new[2019:2118]
uswrf_new11 = uswrf_new[2133:2150]
uswrf_new12 = uswrf_new[2158:2169]
uswrf_new13 = uswrf_new[2179:2227]
uswrf_new14 = uswrf_new[2267:2279]
uswrf_new15 = uswrf_new[2298:2303]
uswrf_new16 = uswrf_new[2566:2571]
uswrf_new17 = uswrf_new[2668:2683]
uswrf_new18 = uswrf_new[2941:2950]
uswrf_new19 = uswrf_new[2953:2959]
uswrf_new20 = uswrf_new[3000:3008]
uswrf_new21 = uswrf_new[3014:3024]
uswrf_new22 = uswrf_new[3028:3036]
uswrf_new23 = uswrf_new[3039:3053]
uswrf_new24 = uswrf_new[3220:3225]
uswrf_new25 = uswrf_new[3228:3233]
uswrf_new26 = uswrf_new[3418:3428]
uswrf_new27 = uswrf_new[3461:3471]
uswrf_new28 = uswrf_new[3584:3595]
uswrf_new29 = uswrf_new[3604:3609]
uswrf_new30 = uswrf_new[3625:3630]
uswrf_new31 = uswrf_new[3635:3657]
uswrf_new32 = uswrf_new[4517:4522]
uswrf_new33 = uswrf_new[4575:4581]
uswrf_new34 = uswrf_new[4695:4703]
uswrf_new35 = uswrf_new[4873:4879]
uswrf_new36 = uswrf_new[5069:5093]
uswrf_new37 = uswrf_new[5163:5169]
uswrf_new38 = uswrf_new[5266:5292]
uswrf_new39 = uswrf_new[5314:5328]
uswrf_new40 = uswrf_new[5769:5793]
uswrf_new41 = uswrf_new[5898:5903]
uswrf_new42 = uswrf_new[5906:5912]
uswrf_new43 = uswrf_new[5923:5928]
shtfl_new92 = shtfl_new[10210:10215]

# %%
shallow_dlwrf = np.concatenate((dlwrf_new15,dlwrf_new16,dlwrf_new18,dlwrf_new21,dlwrf_new41,
                               dlwrf_new42,dlwrf_new43,dlwrf_new50,dlwrf_new51,dlwrf_new52,dlwrf_new55,
                               dlwrf_new83))

shallow_dswrf = np.concatenate((dswrf_new15,dswrf_new16,dswrf_new18,dswrf_new21,dswrf_new41,
                               dswrf_new42,dswrf_new43,dswrf_new50,dswrf_new51,dswrf_new52,dswrf_new55,
                               dswrf_new83))

shallow_ulwrf = np.concatenate((ulwrf_new15,ulwrf_new16,ulwrf_new18,ulwrf_new21,ulwrf_new41,
                               ulwrf_new42,ulwrf_new43,ulwrf_new50,ulwrf_new51,ulwrf_new52,ulwrf_new55,
                               ulwrf_new83))

shallow_uswrf = np.concatenate((uswrf_new15,uswrf_new16,uswrf_new18,uswrf_new21,uswrf_new41,
                               uswrf_new42,uswrf_new43,uswrf_new50,uswrf_new51,uswrf_new52,uswrf_new55,
                               uswrf_new83))

shallow_shtfl = np.concatenate((shtfl_new15,shtfl_new16,shtfl_new18,shtfl_new21,shtfl_new41,
                               shtfl_new42,shtfl_new43,shtfl_new50,shtfl_new51,shtfl_new52,shtfl_new55,
                               shtfl_new83))

shallow_lhtfl = np.concatenate((lhtfl_new15,lhtfl_new16,lhtfl_new18,lhtfl_new21,lhtfl_new41,lhtfl_new42,
                               lhtfl_new43,lhtfl_new50,lhtfl_new51,lhtfl_new52,lhtfl_new55,lhtfl_new83))

# %%
Subsurface_reversed_dlwrf = np.concatenate((dlwrf_new1,dlwrf_new2,dlwrf_new4,dlwrf_new5,
                                           dlwrf_new8,dlwrf_new17,dlwrf_new22,dlwrf_new23,dlwrf_new26,
                                           dlwrf_new27,dlwrf_new29,dlwrf_new30,dlwrf_new32,dlwrf_new33,
                                           dlwrf_new34,dlwrf_new35,dlwrf_new36,dlwrf_new37,dlwrf_new38,
                                           dlwrf_new39,dlwrf_new44,dlwrf_new45,dlwrf_new46,dlwrf_new58,
                                           dlwrf_new59,dlwrf_new60,dlwrf_new61,dlwrf_new62,dlwrf_new64,
                                           dlwrf_new65,dlwrf_new66,dlwrf_new67,dlwrf_new69,dlwrf_new70,
                                           dlwrf_new71,dlwrf_new74,dlwrf_new78,dlwrf_new79,dlwrf_new85,
                                           dlwrf_new87,dlwrf_new88,dlwrf_new89))

Subsurface_reversed_dswrf = np.concatenate((dswrf_new1,dswrf_new2,dswrf_new4,dswrf_new5,
                                           dswrf_new8,dswrf_new17,dswrf_new22,dswrf_new23,dswrf_new26,
                                           dswrf_new27,dswrf_new29,dswrf_new30,dswrf_new32,dswrf_new33,
                                           dswrf_new34,dswrf_new35,dswrf_new36,dswrf_new37,dswrf_new38,
                                           dswrf_new39,dswrf_new44,dswrf_new45,dswrf_new46,dswrf_new58,
                                           dswrf_new59,dswrf_new60,dswrf_new61,dswrf_new62,dswrf_new64,
                                           dswrf_new65,dswrf_new66,dswrf_new67, dswrf_new69, dswrf_new70,
                                           dswrf_new71,dswrf_new74,dswrf_new78,dswrf_new79,dswrf_new85,
                                           dswrf_new87,dswrf_new88,dswrf_new89))

Subsurface_reversed_ulwrf = np.concatenate((ulwrf_new1,ulwrf_new2,ulwrf_new4,ulwrf_new5,
                                           ulwrf_new8,ulwrf_new17,ulwrf_new22,ulwrf_new23,ulwrf_new26,
                                           ulwrf_new27,ulwrf_new29,ulwrf_new30,ulwrf_new32,ulwrf_new33,
                                           ulwrf_new34,ulwrf_new35,ulwrf_new36,ulwrf_new37,ulwrf_new38,
                                           ulwrf_new39,ulwrf_new44,ulwrf_new45,ulwrf_new46,ulwrf_new58,
                                           ulwrf_new59,ulwrf_new60,ulwrf_new61,ulwrf_new62,ulwrf_new64,
                                           ulwrf_new65,ulwrf_new66,ulwrf_new67,ulwrf_new69,ulwrf_new70,
                                           ulwrf_new71,ulwrf_new74,ulwrf_new78,ulwrf_new79,ulwrf_new85,
                                           ulwrf_new87,ulwrf_new88,ulwrf_new89))

Subsurface_reversed_uswrf = np.concatenate((uswrf_new1,uswrf_new2,uswrf_new4,uswrf_new5,
                                           uswrf_new8,uswrf_new17,uswrf_new22,uswrf_new23,uswrf_new26,
                                           uswrf_new27,uswrf_new29,uswrf_new30,uswrf_new32,uswrf_new33,
                                           uswrf_new34,uswrf_new35,uswrf_new36,uswrf_new37,uswrf_new38,
                                           uswrf_new39,uswrf_new44,uswrf_new45,uswrf_new46,uswrf_new58,
                                           uswrf_new59,uswrf_new60,uswrf_new61,uswrf_new62,uswrf_new64,
                                           uswrf_new65,uswrf_new66,uswrf_new67,uswrf_new69,uswrf_new70,
                                           uswrf_new71,uswrf_new74,uswrf_new78,uswrf_new79,uswrf_new85,
                                           uswrf_new87,uswrf_new88,uswrf_new89))

Subsurface_reversed_shtfl = np.concatenate((shtfl_new1,shtfl_new2,shtfl_new4,shtfl_new5,
                                           shtfl_new8,shtfl_new17,shtfl_new22,shtfl_new23,shtfl_new26,
                                           shtfl_new27,shtfl_new29,shtfl_new30,shtfl_new32,shtfl_new33,
                                           shtfl_new34,shtfl_new35,shtfl_new36,shtfl_new37,shtfl_new38,
                                           shtfl_new39,shtfl_new44,shtfl_new45,shtfl_new46,shtfl_new58,
                                           shtfl_new59,shtfl_new60,shtfl_new61,shtfl_new62,shtfl_new64,
                                           shtfl_new65,shtfl_new66,shtfl_new67,shtfl_new69,shtfl_new70,
                                           shtfl_new71,shtfl_new74,shtfl_new78,shtfl_new79,shtfl_new85,
                                           shtfl_new87,shtfl_new88,shtfl_new89))

Subsurface_reversed_lhtfl = np.concatenate((lhtfl_new1,lhtfl_new2,lhtfl_new4,lhtfl_new5,
                                           lhtfl_new8,lhtfl_new17,lhtfl_new22,lhtfl_new23,lhtfl_new26,
                                           lhtfl_new27,lhtfl_new29,lhtfl_new30,lhtfl_new32,lhtfl_new33,
                                           lhtfl_new34,lhtfl_new35,lhtfl_new36,lhtfl_new37,lhtfl_new38,
                                           lhtfl_new39,lhtfl_new44,lhtfl_new45,lhtfl_new46,lhtfl_new58,
                                           lhtfl_new59,lhtfl_new60,lhtfl_new61,lhtfl_new62,lhtfl_new64,
                                           lhtfl_new65,lhtfl_new66,lhtfl_new67,lhtfl_new69,lhtfl_new70,
                                           lhtfl_new71,lhtfl_new74,lhtfl_new78,lhtfl_new79,lhtfl_new85,
                                           lhtfl_new87,lhtfl_new88,lhtfl_new89))

# %%
Subsurface_intensified_dlwrf = np.concatenate((dlwrf_new10,dlwrf_new11,dlwrf_new12,dlwrf_new13,
                                              dlwrf_new14,dlwrf_new19,dlwrf_new20,dlwrf_new24,dlwrf_new25,
                                              dlwrf_new40,dlwrf_new47,dlwrf_new48,dlwrf_new49,dlwrf_new53,
                                              dlwrf_new54,dlwrf_new56,dlwrf_new57,dlwrf_new72,dlwrf_new73,
                                              dlwrf_new76,dlwrf_new77,dlwrf_new80,dlwrf_new81,dlwrf_new82,
                                              dlwrf_new84,dlwrf_new90,dlwrf_new91,dlwrf_new92))

Subsurface_intensified_dswrf = np.concatenate((dswrf_new10,dswrf_new11,dswrf_new12,dswrf_new13,
                                              dswrf_new14,dswrf_new19,dswrf_new20,dswrf_new24,dswrf_new25,
                                              dswrf_new40,dswrf_new47,dswrf_new48,dswrf_new49,dswrf_new53,
                                              dswrf_new54,dswrf_new56,dswrf_new57,dswrf_new72,dswrf_new73,
                                              dswrf_new76,dswrf_new77,dswrf_new80,dswrf_new81,dswrf_new82,
                                              dswrf_new84,dswrf_new90,dswrf_new91,dswrf_new92))

Subsurface_intensified_uswrf = np.concatenate((uswrf_new10,uswrf_new11,uswrf_new12,uswrf_new13,
                                              uswrf_new14,uswrf_new19,uswrf_new20,uswrf_new24,uswrf_new25,
                                              uswrf_new40,uswrf_new47,uswrf_new48,uswrf_new49,uswrf_new53,
                                              uswrf_new54,uswrf_new56,uswrf_new57,uswrf_new72,uswrf_new73,
                                              uswrf_new76,uswrf_new77,uswrf_new80,uswrf_new81,uswrf_new82,
                                              uswrf_new84,uswrf_new90,uswrf_new91,uswrf_new92))

Subsurface_intensified_ulwrf = np.concatenate((ulwrf_new10,ulwrf_new11,ulwrf_new12,ulwrf_new13,
                                              ulwrf_new14,ulwrf_new19,ulwrf_new20,ulwrf_new24,ulwrf_new25,
                                              ulwrf_new40,ulwrf_new47,ulwrf_new48,ulwrf_new49,ulwrf_new53,
                                              ulwrf_new54,ulwrf_new56,ulwrf_new57,ulwrf_new72,ulwrf_new73,
                                              ulwrf_new76,ulwrf_new77,ulwrf_new80,ulwrf_new81,ulwrf_new82,
                                              ulwrf_new84,ulwrf_new90,ulwrf_new91,ulwrf_new92))

Subsurface_intensified_shtfl = np.concatenate((shtfl_new10,shtfl_new11,shtfl_new12,shtfl_new13,
                                              shtfl_new14,shtfl_new19,shtfl_new20,shtfl_new24,shtfl_new25,
                                              shtfl_new40,shtfl_new47,shtfl_new48,shtfl_new49,shtfl_new53,
                                              shtfl_new54,shtfl_new56,shtfl_new57,shtfl_new72,shtfl_new73,
                                              shtfl_new76,shtfl_new77,shtfl_new80,shtfl_new81,shtfl_new82,
                                              shtfl_new84,shtfl_new90,shtfl_new91,shtfl_new92))

Subsurface_intensified_lhtfl = np.concatenate((lhtfl_new10,lhtfl_new11,lhtfl_new12,lhtfl_new13,
                                              lhtfl_new14,lhtfl_new19,lhtfl_new20,lhtfl_new24,lhtfl_new25,
                                              lhtfl_new40,lhtfl_new47,lhtfl_new48,lhtfl_new49,lhtfl_new53,
                                              lhtfl_new54,lhtfl_new56,lhtfl_new57,lhtfl_new72,lhtfl_new73,
                                              lhtfl_new76,lhtfl_new77,lhtfl_new80,lhtfl_new81,lhtfl_new82,
                                              lhtfl_new84,lhtfl_new90,lhtfl_new91,lhtfl_new92))

# %%
Deep_dlwrf = dlwrf_new75
Deep_dswrf = dswrf_new75
Deep_ulwrf = ulwrf_new75
Deep_uswrf = uswrf_new75
Deep_shtfl = shtfl_new75
Deep_lhtfl = lhtfl_new75

# %%
Subsurface_intensified_Reversed_dlwrf = np.concatenate((dlwrf_new3,dlwrf_new6,dlwrf_new7,
                                                       dlwrf_new9,dlwrf_new28,dlwrf_new31,dlwrf_new63,
                                                       dlwrf_new68,dlwrf_new86))

Subsurface_intensified_Reversed_dswrf = np.concatenate((dswrf_new3,dswrf_new6,dswrf_new7,
                                                       dswrf_new9,dswrf_new28,dswrf_new31,dswrf_new63,
                                                       dswrf_new68,dswrf_new86))

Subsurface_intensified_Reversed_ulwrf = np.concatenate((ulwrf_new3,ulwrf_new6,ulwrf_new7,
                                                       ulwrf_new9,ulwrf_new28,ulwrf_new31,ulwrf_new63,
                                                       ulwrf_new68,ulwrf_new86))

Subsurface_intensified_Reversed_uswrf = np.concatenate((uswrf_new3,uswrf_new6,uswrf_new7,
                                                       uswrf_new9,uswrf_new28,uswrf_new31,uswrf_new63,
                                                       uswrf_new68,uswrf_new86))

Subsurface_intensified_Reversed_shtfl = np.concatenate((shtfl_new3,shtfl_new6,shtfl_new7,
                                                       shtfl_new9,shtfl_new28,shtfl_new31,shtfl_new63,
                                                       shtfl_new68,shtfl_new86))

Subsurface_intensified_Reversed_lhtfl = np.concatenate((lhtfl_new3,lhtfl_new6,lhtfl_new7,
                                                       lhtfl_new9,lhtfl_new28,lhtfl_new31,lhtfl_new63,
                                                       lhtfl_new68,lhtfl_new86))

# %%
data_mld = np.load('./south_93_20_mld_last.npz')['mld']

# %%
mld = data_mld

# %%
mld1 = mld[1281:1297]
mld2 = mld[1743:1750]
mld3 = mld[1755:1762]
mld4 = mld[1788:1805]
mld5 = mld[1819:1851]
mld6 = mld[1867:1929]
mld7 = mld[1945:1950]
mld8 = mld[1955:1971]
mld9 = mld[1987:2004]
mld10 = mld[2019:2118]
mld11 = mld[2133:2150]
mld12 = mld[2158:2169]
mld13 = mld[2179:2227]
mld14 = mld[2267:2279]
mld15 = mld[2298:2303]
mld16 = mld[2566:2571]
mld17 = mld[2668:2683]
mld18 = mld[2941:2950]
mld19 = mld[2953:2959]
mld20 = mld[3000:3008]
mld21 = mld[3014:3024]
mld22 = mld[3028:3036]
mld23 = mld[3039:3053]
mld24 = mld[3220:3225]
mld25 = mld[3228:3233]
mld26 = mld[3418:3428]
mld27 = mld[3461:3471]
mld28 = mld[3584:3595]
mld29 = mld[3604:3609]
mld30 = mld[3625:3630]
mld31 = mld[3635:3657]
mld32 = mld[4517:4522]
mld33 = mld[4575:4581]
mld34 = mld[4695:4703]
mld35 = mld[4873:4879]
mld36 = mld[5069:5093]
mld37 = mld[5163:5169]
mld38 = mld[5266:5292]
mld39 = mld[5314:5328]
mld40 = mld[5769:5793]
mld41 = mld[5898:5903]
mld42 = mld[5906:5912]
mld43 = mld[5923:5928]
mld44 = mld[6240:6254]
mld45 = mld[6263:6277]
mld46 = mld[6345:6361]
mld47 = mld[6370:6413]
mld48 = mld[6422:6450]
mld49 = mld[6472:6501]
mld50 = mld[7002:7008]
mld51 = mld[7015:7022]
mld52 = mld[7044:7076]
mld53 = mld[7264:7305]
mld54 = mld[7309:7314]
mld55 = mld[7385:7401]
mld56 = mld[7432:7477]
mld57 = mld[7494:7499]
mld58 = mld[7784:7795]
mld59 = mld[7799:7835]
mld60 = mld[7851:7860]
mld61 = mld[7901:7909]
mld62 = mld[7912:7917]
mld63 = mld[7998:8011]
mld64 = mld[8161:8210]
mld65 = mld[8243:8253]
mld66 = mld[8260:8268]
mld67 = mld[8278:8324]
mld68 = mld[8342:8431]
mld69 = mld[8512:8592]
mld70 = mld[8595:8626]
mld71 = mld[8636:8648]
mld72 = mld[8719:8762]
mld73 = mld[8769:8788]
mld74 = mld[8893:8900]
mld75 = mld[8988:9000]
mld76 = mld[9029:9057]
mld77 = mld[9086:9108]
mld78 = mld[9191:9196]
mld79 = mld[9266:9288]
mld80 = mld[9465:9514]
mld81 = mld[9544:9549]
mld82 = mld[9553:9566]
mld83 = mld[9591:9618]
mld84 = mld[9629:9677]
mld85 = mld[9770:9783]
mld86 = mld[9789:9807]
mld87 = mld[9867:9877]
mld88 = mld[9885:9891]
mld89 = mld[9940:9957]
mld90 = mld[9987:10154]
mld91 = mld[10188:10195]
mld92 = mld[10210:10215]

# %%
Shallow_mld = np.concatenate((mld15,mld16,mld18,mld21,mld41,mld42,mld43,mld50,mld51,
                             mld52,mld55,mld83))

Subsurface_reversed_mld = np.concatenate((mld1,mld2,mld4,mld5,mld8,mld17,mld22,mld23,
                                         mld26,mld27,mld29,mld30,mld32,mld33,mld34,mld35,mld36,mld37,
                                         mld38,mld39,mld44,mld45,mld46,mld58,mld59,mld60,mld61,
                                         mld62,mld64,mld65,mld66,mld67,mld69,mld70,mld71,mld74,mld78,
                                         mld79,mld85,mld87,mld88,mld89))

Subsurface_intensified_mld = np.concatenate((mld10,mld11,mld12,mld13,mld14,mld19,mld20,
                                            mld24,mld25,mld40,mld47,mld48,mld49,mld53,mld54,mld56,mld57,
                                            mld72,mld73,mld76,mld77,mld80,mld81,mld82,mld84,mld90,mld91,
                                            mld92))

Deep_mld = mld75

Subsurface_intensified_Reversed_mld = np.concatenate((mld3,mld6,mld7,mld9,mld28,mld31,
                                                     mld63,mld68,mld86))

# %%
def t_surfaceforcing(Qnet, Qdsw, mld, *args):
    # Description - surface forcing term of heat budget
    # input
    # Qnet - 3D daily net air-sea heat flux data to calculate surface forcing term of heat budget, specified as a
    #   three dimensions matrix m-by-n-by-t. m and n separately indicate two spatial dimensions
    #   and t indicates temporal dimension.
    # Qdsw - 3D daily downward shortwave radiation data to calculate surface forcing term of heat budget, specified as a
    #   three dimensions matrix m-by-n-by-t. m and n separately indicate two spatial dimensions
    #   and t indicates temporal dimension.
    # mld - 3D daily mixed-layer depth data to calculate surface forcing term of heat budget, specified as a
    #   three dimensions matrix m-by-n-by-t. m and n separately indicate two spatial dimensions
    #   and t indicates temporal dimension.
    # Q & Qdsw & mld must have the same dimensions.
    # rho - seawater density, default is 1025 kg/m3.
    # Cp - seawater heat capacity, default is 3986 J/(kg°C).
    # r, c1, c2 - defaults are 0.58, 0.35, 23, respectively. (Paulson and Simpon, 1977)
    # output
    # sf - surface forcing term of heat budget

    paramNames = ['rho', 'Cp', 'r', 'c1', 'c2']
    defaults = [1025, 3986, 0.58, 0.35, 23]

    # Parsing optional arguments
    rho, Cp, r, c1, c2 = defaults[:len(args)] if len(args) > 0 else defaults

    Qd = Qdsw * (r * np.exp(-mld / c1) + (1 - r) * np.exp(
        -mld / c2))  # shortwave radiation penetrating below the mixed layer
    sf0 = (Qnet - Qd) / rho / Cp / mld * 3600 * 24  # unit: °C/day
    sf = (sf0[:, :, :-1] + sf0[:, :, 1:]) / 2

    return sf

# %%
Shallow_Qnet = shallow_dswrf - shallow_uswrf + shallow_dlwrf - shallow_ulwrf + shallow_shtfl -shallow_lhtfl
Shallow_Qdsw = shallow_dswrf
Shallow_mld =  Shallow_mld

# %%
Subsurface_reversed_Qnet = Subsurface_reversed_dswrf - Subsurface_reversed_uswrf + Subsurface_reversed_dlwrf - Subsurface_reversed_ulwrf + Subsurface_reversed_shtfl - Subsurface_reversed_lhtfl
Subsurface_reversed_Qdsw = Subsurface_reversed_dswrf
Subsurface_reversed_mld = Subsurface_reversed_mld

# %%
Subsurface_intensified_Qnet = Subsurface_intensified_dswrf - Subsurface_intensified_uswrf + Subsurface_intensified_dlwrf - Subsurface_intensified_ulwrf + Subsurface_intensified_shtfl - Subsurface_intensified_lhtfl
Subsurface_intensified_Qdsw = Subsurface_intensified_dswrf
Subsurface_intensified_mld = Subsurface_intensified_mld

# %%
Deep_Qnet = Deep_dswrf - Deep_uswrf + Deep_dlwrf - Deep_ulwrf + Deep_shtfl -Deep_lhtfl
Deep_Qdsw = Deep_dswrf
Deep_mld =  Deep_mld

# %%
Subsurface_intensified_Reversed_Qnet = Subsurface_intensified_Reversed_dswrf - Subsurface_intensified_Reversed_uswrf + Subsurface_intensified_Reversed_dlwrf - Subsurface_intensified_Reversed_ulwrf + Subsurface_intensified_Reversed_shtfl -Subsurface_intensified_Reversed_lhtfl
Subsurface_intensified_Reversed_Qdsw = Subsurface_intensified_Reversed_dswrf
Subsurface_intensified_Reversed_mld =  Subsurface_intensified_Reversed_mld

# %%
Subsurface_intensified_Reversed_Qnet.shape
# Out:
# (244, 241, 241)

# %%
Shallow_mld = np.where(Shallow_mld<-100, np.nan, Shallow_mld)

# %%
Shallow_Qnet.shape
# Out:
# (133, 241, 241)

# %%
Shallow_Qdsw.shape
# Out:
# (133, 241, 241)

# %%
Shallow_mld.shape
# Out:
# (133, 241, 241)

# %%
Shallow_sf = t_surfaceforcing(Shallow_Qnet, Shallow_Qdsw, Shallow_mld)
Subsurface_reversed_sf = t_surfaceforcing(Subsurface_reversed_Qnet, Subsurface_reversed_Qdsw, Subsurface_reversed_mld)
Subsurface_intensified_sf = t_surfaceforcing(Subsurface_intensified_Qnet, Subsurface_intensified_Qdsw, Subsurface_intensified_mld)
Deep_sf = t_surfaceforcing(Deep_Qnet, Deep_Qdsw, Deep_mld)
Subsurface_intensified_Reversed_sf = t_surfaceforcing(Subsurface_intensified_Reversed_Qnet, Subsurface_intensified_Reversed_Qdsw, Subsurface_intensified_Reversed_mld)
# Out:
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_30136/3671221539.py:26: RuntimeWarning: overflow encountered in exp
#   Qd = Qdsw * (r * np.exp(-mld / c1) + (1 - r) * np.exp(
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_30136/3671221539.py:29: RuntimeWarning: invalid value encountered in add
#   sf = (sf0[:, :, :-1] + sf0[:, :, 1:]) / 2

# %%
Shallow_sf_mean = np.nanmean(Shallow_sf, axis = 0)
Subsurface_reversed_sf_mean = np.nanmean(Subsurface_reversed_sf, axis = 0)
Subsurface_intensified_sf_mean = np.nanmean(Subsurface_intensified_sf, axis = 0)
Deep_sf_mean = np.nanmean(Deep_sf, axis = 0)
Subsurface_intensified_Reversed_sf_mean = np.nanmean(Subsurface_intensified_Reversed_sf, axis = 0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.cm as cm

# Create a 2D array of random numbers
data = Subsurface_intensified_Reversed_sf_mean

plt.figure(dpi=300)  # Set the dpi value

colors = ['#b9c4d8', '#a6b4cc', '#8ca5dc', '#8897e3', '#a4badc', '#adc2de', '#b0cada', '#bbcde9',
'#c3d2eb', '#d5e0f0', '#ebf1f7', '#f7fbfd', '#fcfefc', '#fdfdfe', '#fdfdfe', '#fefefe',
'#fff8f2','#fffaf3', '#fff4ea', '#ffeacc', '#ffd9c1', '#ffcfae', '#ffbf9e', '#ffbfa0',
'#f7aba0', '#f3a89a', '#f0a093', '#eb998c', '#e69185', '#e68b7e', '#db6f6d', '#da6e6d',
'#d26967', '#c9615d'
          ]
cmap_custom = ListedColormap(colors)
cmap_custom.set_bad(color='lightgrey')  # set the color for NaN values to lightgrey

# Create a ScalarMappable with a normalized color map
norm = BoundaryNorm([-3, -1.5, -0.5, -0.25, -0.125, -0.075, -0.05, -0.0375, -0.025, -0.0185, -0.01,
                     -0.0075, -0.005, -0.00375, -0.0025, -0.00125, 0, 0.00125,
                     0.0025, 0.00375, 0.005, 0.00075, 0.01, 0.0125, 0.025, 0.0375, 0.05, 0.075, 0.125,
                     0.25, 0.5, 1, 1.5], cmap_custom.N)
sm = cm.ScalarMappable(cmap=cmap_custom, norm=norm)
sm.set_array([])

plt.imshow(data, cmap=cmap_custom, norm=norm, interpolation='bicubic', alpha=0.8)

# Add the color bar with the custom color map

cbar = plt.colorbar(sm, shrink=0.85)
cbar.set_ticks([-1.5, -0.025, 0, 0.025, 1.5])  # Optional: Set custom ticks
cbar.set_ticklabels([-1.5, -0.025, 0, 0.025, 1.5])  # Optional: Set custom tick labels

# plt.xticks([0, 60, 120, 180, 240], ['105°E', '110°E', '115°E', '120°E', '125°E'])  
# plt.yticks([0, 60, 120, 180, 240], ['25°N', '20°N', '15°N', '10°N', '5°N'])  
plt.xticks([])
plt.yticks([])

plt.title('Intensified_Reversed MHW Sf')

cbar.set_label('℃/day', rotation=0, labelpad=-40) 
cbar.ax.yaxis.set_label_coords(0.7, -0.03)

plt.tick_params(axis='x', direction='in', length=2, width=1, colors='k', grid_color='r')
plt.tick_params(axis='y', direction='in', length=2, width=1, colors='k', grid_color='r')

plt.show()

# %%
np.savez(r'./Sf.npz',
        Shallow_sf_mean = Shallow_sf_mean, Subsurface_reversed_sf_mean  = Subsurface_reversed_sf_mean,
        Subsurface_intensified_sf_mean = Subsurface_intensified_sf_mean, Deep_sf_mean = Deep_sf_mean,
        Subsurface_intensified_Reversed_sf_mean = Subsurface_intensified_Reversed_sf_mean)

# %%
Shallow_sf_mean = np.nanmean(Shallow_sf, axis = 0)
Subsurface_reversed_sf_mean = np.nanmean(Subsurface_reversed_sf, axis = 0)
Subsurface_intensified_sf_mean = np.nanmean(Subsurface_intensified_sf, axis = 0)
Deep_sf_mean = np.nanmean(Deep_sf, axis = 0)
Subsurface_intensified_Reversed_sf_mean = np.nanmean(Subsurface_intensified_Reversed_sf, axis = 0)

# %%
mld = datan['mld']
mld.shape
# Out:
# (10227, 241, 241)

# %%
from netCDF4 import Dataset, num2date

path = r'D:\uswrf\uswrf.sfc.gauss.1993.nc'
nc0 = Dataset(path)
nc0.variables
# Out:
# {'lat': <class 'netCDF4._netCDF4.Variable'>
#  float32 lat(lat)
#      units: degrees_north
#      actual_range: [ 88.542 -88.542]
#      long_name: Latitude
#      standard_name: latitude
#      axis: Y
#      coordinate_defines: point
#  unlimited dimensions:
#  current shape = (94,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'lon': <class 'netCDF4._netCDF4.Variable'>
#  float32 lon(lon)
#      units: degrees_east
#      long_name: Longitude
#      actual_range: [  0.    358.125]
#      standard_name: longitude
#      axis: X
#      coordinate_defines: point
#  unlimited dimensions:
#  current shape = (192,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'time_bnds': <class 'netCDF4._netCDF4.Variable'>
#  float64 time_bnds(time, nbnds)
#      long_name: Time Boundaries
#  unlimited dimensions: time
#  current shape = (365, 2)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'time': <class 'netCDF4._netCDF4.Variable'>
# ...

# %%
datan = np.load(r'D:\博士工作\统计第二篇_3DMHW_MLD_south\mld_93_20_Noaa_chahi.npz')['mld']

# %%
datan.shape
# Out:
# (10227, 12, 12)

# %%
def rotate_array_anticlockwise(array):
    n = len(array)
    # 创建一个新的数组来存储旋转后的结果
    rotated_array = [[0 for _ in range(n)] for _ in range(n)]
    
    for i in range(n):
        for j in range(n):
            # 将原数组中的元素按逆时针顺序放入新数组
            rotated_array[n-1-j][i] = array[i][j]
            
    return rotated_array

# %%
list = []

for i in range(10227):
    data_mld = datan[i]
    data_rotated = rotate_array_anticlockwise(data_mld)
    list.append(data_rotated)
mld_list = np.array(list)

# %%
mld_list.reshape(-1,12,12)
mld_list.shape
# Out:
# (10227, 12, 12)

# %%
np.savez(r'D:\博士工作\统计第二篇_3DMHW_MLD_south\最终位置\mld_93_20_Noaa_chahi.npz',
        mld = mld_list)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data

# Display using imshow
plt.imshow(mld_list[0,:,:], cmap='viridis')
plt.show()
