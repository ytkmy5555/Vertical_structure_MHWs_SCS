# %%
import numpy as np

# %%
def t_tendency(mlt):
    # Description - temperature tendency term of heat budget
    # input
    # mlt - 3D daily mixed-layer temperature data to calculate tendency of heat budget, specified as a
    #   three dimensions matrix m-by-n-by-t. m and n separately indicate two spatial dimensions
    #   and t indicates temporal dimension.
    # output
    # tt - temperature tendency
    tt = mlt[:, :, 1:] - mlt[:, :, :-1]  # unit: deg/day
    return tt

# %%
mlt = np.load('./south_93_20_temp_surface.npz')['temp']

# %%
mlt = np.where(mlt<-100, np.nan, mlt)
mlt.shape
# Out:
# (10227, 241, 241)

# %%
mlt1 = mlt.transpose(1,2,0)

# %%
mlt1.shape
# Out:
# (241, 241, 10227)

# %%
tt = t_tendency(mlt1)

# %%
tt.shape
# Out:
# (241, 241, 10226)

# %%
tt = tt.transpose(2,0,1)
tt.shape
# Out:
# (10226, 241, 241)

# %%
tt1 = tt[1281:1297]
tt2 = tt[1743:1750]
tt3 = tt[1755:1762]
tt4 = tt[1788:1805]
tt5 = tt[1819:1851]
tt6 = tt[1867:1929]
tt7 = tt[1945:1950]
tt8 = tt[1955:1971]
tt9 = tt[1987:2004]
tt10 = tt[2019:2118]
tt11 = tt[2133:2150]
tt12 = tt[2158:2169]
tt13 = tt[2179:2227]
tt14 = tt[2267:2279]
tt15 = tt[2298:2303]
tt16 = tt[2566:2571]
tt17 = tt[2668:2683]
tt18 = tt[2941:2950]
tt19 = tt[2953:2959]
tt20 = tt[3000:3008]
tt21 = tt[3014:3024]
tt22 = tt[3028:3036]
tt23 = tt[3039:3053]
tt24 = tt[3220:3225]
tt25 = tt[3228:3233]
tt26 = tt[3418:3428]
tt27 = tt[3461:3471]
tt28 = tt[3584:3595]
tt29 = tt[3604:3609]
tt30 = tt[3625:3630]
tt31 = tt[3635:3657]
tt32 = tt[4517:4522]
tt33 = tt[4575:4581]
tt34 = tt[4695:4703]
tt35 = tt[4873:4879]
tt36 = tt[5069:5093]
tt37 = tt[5163:5169]
tt38 = tt[5266:5292]
tt39 = tt[5314:5328]
tt40 = tt[5769:5793]
tt41 = tt[5898:5903]
tt42 = tt[5906:5912]
tt43 = tt[5923:5928]
tt44 = tt[6240:6254]
tt45 = tt[6263:6277]
tt46 = tt[6345:6361]
tt47 = tt[6370:6413]
tt48 = tt[6422:6450]
tt49 = tt[6472:6501]
tt50 = tt[7002:7008]
tt51 = tt[7015:7022]
tt52 = tt[7044:7076]
tt53 = tt[7264:7305]
tt54 = tt[7309:7314]
tt55 = tt[7385:7401]
tt56 = tt[7432:7477]
tt57 = tt[7494:7499]
tt58 = tt[7784:7795]
tt59 = tt[7799:7835]
tt60 = tt[7851:7860]
tt61 = tt[7901:7909]
tt62 = tt[7912:7917]
tt63 = tt[7998:8011]
tt64 = tt[8161:8210]
tt65 = tt[8243:8253]
tt66 = tt[8260:8268]
tt67 = tt[8278:8324]
tt68 = tt[8342:8431]
tt69 = tt[8512:8592]
tt70 = tt[8595:8626]
tt71 = tt[8636:8648]
tt72 = tt[8719:8762]
tt73 = tt[8769:8788]
tt74 = tt[8893:8900]
tt75 = tt[8988:9000]
tt76 = tt[9029:9057]
tt77 = tt[9086:9108]
tt78 = tt[9191:9196]
tt79 = tt[9266:9288]
tt80 = tt[9465:9514]
tt81 = tt[9544:9549]
tt82 = tt[9553:9566]
tt83 = tt[9591:9618]
tt84 = tt[9629:9677]
tt85 = tt[9770:9783]
tt86 = tt[9789:9807]
tt87 = tt[9867:9877]
tt88 = tt[9885:9891]
tt89 = tt[9940:9957]
tt90 = tt[9987:10154]
tt91 = tt[10188:10195]
tt92 = tt[10210:10215]

# %%
Shallow_tt = np.concatenate((tt15,tt16,tt18,tt21,tt41,tt42,tt43,tt50,tt51,tt52,tt55,tt83))

Subsurface_reversed_tt = np.concatenate((tt1, tt2, tt4, tt5, tt8, tt17, tt22, tt23, tt26, tt27, tt29,
                                        tt30, tt32, tt33, tt34, tt35, tt36, tt37, tt38, tt39, tt44, tt45, tt46, tt58,
                                        tt59, tt60, tt61, tt62, tt64, tt65, tt66, tt67, tt69, tt70, tt71, tt74, tt78,
                                        tt79, tt85, tt87, tt88, tt89))

Subsurface_intensified_tt = np.concatenate((tt10, tt11, tt12, tt13, tt14, tt19, tt20, tt24, tt25, tt40,
                                           tt47, tt48, tt49, tt53, tt54, tt56, tt57, tt72, tt73, tt76, tt77, tt80,
                                           tt81, tt82, tt84, tt90, tt91, tt92))

Deep_tt =  tt75

Subsurface_intensified_Reversed_tt = np.concatenate((tt3, tt6, tt7, tt9, tt28, tt31, tt63, tt68, tt86))

# %%
shallow_tt_mean = np.nanmean(Shallow_tt, axis = 0)
Subsurface_reversed_tt_mean = np.nanmean(Subsurface_reversed_tt, axis = 0)
Subsurface_intensified_tt_mean = np.nanmean(Subsurface_intensified_tt, axis = 0)
Deep_tt_mean = np.nanmean(Deep_tt, axis = 0)
Subsurface_intensified_Reversed_tt_mean = np.nanmean(Subsurface_intensified_Reversed_tt, axis = 0)
# Out:
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_9876/241946940.py:1: RuntimeWarning: Mean of empty slice
#   shallow_tt_mean = np.nanmean(Shallow_tt, axis = 0)
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_9876/241946940.py:2: RuntimeWarning: Mean of empty slice
#   Subsurface_reversed_tt_mean = np.nanmean(Subsurface_reversed_tt, axis = 0)
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_9876/241946940.py:3: RuntimeWarning: Mean of empty slice
#   Subsurface_intensified_tt_mean = np.nanmean(Subsurface_intensified_tt, axis = 0)
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_9876/241946940.py:4: RuntimeWarning: Mean of empty slice
#   Deep_tt_mean = np.nanmean(Deep_tt, axis = 0)
# C:\Users\mymylove\AppData\Local\Temp/ipykernel_9876/241946940.py:5: RuntimeWarning: Mean of empty slice
#   Subsurface_intensified_Reversed_tt_mean = np.nanmean(Subsurface_intensified_Reversed_tt, axis = 0)

# %%
list3 = []
for i in range(241):
    for j in range(241):
        list3.append(shallow_tt_mean[-i-1, j])

shallow_tt_mean0 = np.array(list3)
shallow_tt_mean0 = shallow_tt_mean0.reshape(241,241)

list4 = []
for i in range(241):
    for j in range(241):
        list4.append(Subsurface_reversed_tt_mean[-i-1, j])

Subsurface_reversed_tt_mean0 = np.array(list4)
Subsurface_reversed_tt_mean0 = Subsurface_reversed_tt_mean0.reshape(241,241)


list5 = []
for i in range(241):
    for j in range(241):
        list5.append(Subsurface_intensified_tt_mean[-i-1, j])

Subsurface_intensified_tt_mean0 = np.array(list5)
Subsurface_intensified_tt_mean0 = Subsurface_intensified_tt_mean0.reshape(241,241)

list6 = []
for i in range(241):
    for j in range(241):
        list6.append(Deep_tt_mean[-i-1, j])

Deep_tt_mean0 = np.array(list6)
Deep_tt_mean0 = Deep_tt_mean0.reshape(241,241)


list8 = []
for i in range(241):
    for j in range(241):
        list8.append(Subsurface_intensified_Reversed_tt_mean[-i-1, j])

Subsurface_intensified_Reversed_tt_mean0 = np.array(list8)
Subsurface_intensified_Reversed_tt_mean0 = Subsurface_intensified_Reversed_tt_mean0.reshape(241,241)

# %%
np.savez('./Tt.npz',
        Shallow_sf_mean = shallow_tt_mean0, 
         Subsurface_reversed_sf_mean  = Subsurface_reversed_tt_mean0,
        Subsurface_intensified_sf_mean = Subsurface_intensified_tt_mean0, 
         Deep_sf_mean = Deep_tt_mean0,
        Subsurface_intensified_Reversed_sf_mean = Subsurface_intensified_Reversed_tt_mean0)

# %%
shallow_tt_mean0.shape
# Out:
# (241, 241)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.cm as cm

# Create a 2D array of random numbers
data = Subsurface_intensified_Reversed_tt_mean0

plt.figure(dpi=300)  # Set the dpi value

colors = ['#b9c4d8', '#a6b4cc', '#8ca5dc', '#8897e3', '#a4badc', '#adc2de', '#b0cada', '#bbcde9',
'#c3d2eb', '#d5e0f0', '#ebf1f7', '#f7fbfd', '#fcfefc', '#fdfdfe', '#fdfdfe', '#fefefe',
'#fff8f2','#fffaf3', '#fff4ea', '#ffeacc', '#ffd9c1', '#ffcfae', '#ffbf9e', '#ffbfa0',
'#f7aba0', '#f3a89a', '#f0a093', '#eb998c', '#e69185', '#e68b7e', '#db6f6d', '#da6e6d',
'#d26967', '#c9615d'
          ]
cmap_custom = ListedColormap(colors)
cmap_custom.set_bad(color='lightgrey')  # set the color for NaN values to lightgrey

# Create a ScalarMappable with a normalized color map
norm = BoundaryNorm([-3, -1.5, -0.5, -0.25, -0.125, -0.075, -0.05, -0.0375, -0.025, -0.0185, -0.01,
                     -0.0075, -0.005, -0.00375, -0.0025, -0.00125, 0, 0.00125,
                     0.0025, 0.00375, 0.005, 0.00075, 0.01, 0.0125, 0.025, 0.0375, 0.05, 0.075, 0.125,
                     0.25, 0.5, 1, 1.5], cmap_custom.N)
sm = cm.ScalarMappable(cmap=cmap_custom, norm=norm)
sm.set_array([])

plt.imshow(data, cmap=cmap_custom, norm=norm, interpolation='bicubic', alpha=0.8)

# Add the color bar with the custom color map

cbar = plt.colorbar(sm, shrink=0.85)
cbar.set_ticks([-1.5, -0.025, 0, 0.025, 1.5])  # Optional: Set custom ticks
cbar.set_ticklabels([-1.5, -0.025, 0, 0.025, 1.5])  # Optional: Set custom tick labels

# plt.xticks([0, 60, 120, 180, 240], ['105°E', '110°E', '115°E', '120°E', '125°E'])  
# plt.yticks([0, 60, 120, 180, 240], ['25°N', '20°N', '15°N', '10°N', '5°N'])  
plt.xticks([])
plt.yticks([])
plt.title('Intensified_Reversed MHW Tt')

cbar.set_label('℃/day', rotation=0, labelpad=-40) 
cbar.ax.yaxis.set_label_coords(0.7, -0.03)

plt.tick_params(axis='x', direction='in', length=2, width=1, colors='k', grid_color='r')
plt.tick_params(axis='y', direction='in', length=2, width=1, colors='k', grid_color='r')

plt.show()

# %%
shallow_tt_mean0
# Out:
# array([[        nan,         nan,         nan, ...,  0.00513662,
#          0.00215928,  0.00099879],
#        [        nan,         nan,         nan, ..., -0.00399515,
#         -0.00187392,  0.0013222 ],
#        [        nan,         nan,         nan, ..., -0.0024066 ,
#         -0.00275856,  0.00827567],
#        ...,
#        [ 0.06287606,  0.0641507 ,  0.06451217, ...,  0.05121402,
#          0.05030085,  0.04895962],
#        [ 0.06093555,  0.06224825,  0.06293313, ...,  0.0470096 ,
#          0.05047207,  0.04928303],
#        [ 0.05873822,  0.05992725,  0.06092604, ...,  0.05440063,
#          0.05434356,  0.047704  ]])

# %%
17.98906 + 4.19517  #raw
# Out:
# 22.18423

# %%
22.18423 + 40.17328 + 22.18423 + 22.18423
# Out:
# 106.72597
