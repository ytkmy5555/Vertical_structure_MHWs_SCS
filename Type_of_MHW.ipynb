# %%
import numpy as np

# %%
data1 = np.load('./temp_diff_clim_93_20.npz')
data1.files
# Out:
# ['lat', 'lon', 'depth', 'temp_clim_anom']

# %%
lat = data1['lat']
lat
# Out:
# array([[ 5. ],
#        [ 5.5],
#        [ 6. ],
#        [ 6.5],
#        [ 7. ],
#        [ 7.5],
#        [ 8. ],
#        [ 8.5],
#        [ 9. ],
#        [ 9.5],
#        [10. ],
#        [10.5],
#        [11. ],
#        [11.5],
#        [12. ],
#        [12.5],
#        [13. ],
#        [13.5],
#        [14. ],
#        [14.5],
#        [15. ],
#        [15.5],
#        [16. ],
#        [16.5],
#        [17. ],
#        [17.5],
#        [18. ],
#        [18.5],
#        [19. ],
#        [19.5],
#        [20. ],
#        [20.5],
#        [21. ],
#        [21.5],
#        [22. ],
#        [22.5],
#        [23. ],
#        [23.5],
#        [24. ],
#        [24.5],
#        [25. ]], dtype=float32)

# %%
lon = data1['lon']
lon
# Out:
# array([[105. ],
#        [105.5],
#        [106. ],
#        [106.5],
#        [107. ],
#        [107.5],
#        [108. ],
#        [108.5],
#        [109. ],
#        [109.5],
#        [110. ],
#        [110.5],
#        [111. ],
#        [111.5],
#        [112. ],
#        [112.5],
#        [113. ],
#        [113.5],
#        [114. ],
#        [114.5],
#        [115. ],
#        [115.5],
#        [116. ],
#        [116.5],
#        [117. ],
#        [117.5],
#        [118. ],
#        [118.5],
#        [119. ],
#        [119.5],
#        [120. ],
#        [120.5],
#        [121. ],
#        [121.5],
#        [122. ],
#        [122.5],
#        [123. ],
#        [123.5],
#        [124. ],
#        [124.5],
#        [125. ]], dtype=float32)

# %%
temp = data1['temp_clim_anom'][:]
temp.shape
# Out:
# (10227, 55, 41, 41)

# %%
from datetime import datetime

date_str1 = '1993-01-01'
date_str2 = '1997-10-17'

date1 = datetime.strptime(date_str1, '%Y-%m-%d')
date2 = datetime.strptime(date_str2, '%Y-%m-%d')

delta = date2 - date1

print(delta.days)
# Out:
# 1750

# %%
temp_mean = np.nanmean(temp, axis = (2,3))
temp_mean.shape
# Out:
# (10227, 55)

# %%
temp_deviation = np.nanstd(temp, axis=(2,3))
temp_deviation.shape
# Out:
# (10227, 55)

# %%
#MHW9 1996-7-5  ... 1996-7-20
temp_mean1 = temp_mean[1281:1297,:]
temp_deviation1 = temp_deviation[1281:1297,:]

# %%
#MHW10 1997-10-10  ... 1997-10-16
temp_mean2 = temp_mean[1743:1750,:]
temp_deviation2 = temp_deviation[1743:1750,:]

# %%
#MHW11 1997-10-22  ... 1997-10-28
temp_mean3 = temp_mean[1755:1762,:]
temp_deviation3 = temp_deviation[1755:1762,:]

# %%
#MHW12 1997-11-24  ... 1997-12-10
temp_mean4 = temp_mean[1788:1805,:]
temp_deviation4 = temp_deviation[1788:1805,:]

# %%
#MHW13 1997-12-25  ... 1998-1-25
temp_mean5 = temp_mean[1819:1851,:]
temp_deviation5 = temp_deviation[1819:1851,:]

# %%
#MHW14 1998-2-11  ... 1998-4-13
temp_mean6 = temp_mean[1867:1929,:]
temp_deviation6 = temp_deviation[1867:1929,:]

# %%
#MHW15 1998-4-30  ... 1998-5-4
temp_mean7 = temp_mean[1945:1950,:]
temp_deviation7 = temp_deviation[1945:1950,:]

# %%
#MHW16 1998-5-10  ... 1998-5-25
temp_mean8 = temp_mean[1955:1971,:]
temp_deviation8 = temp_deviation[1955:1971,:]

# %%
#MHW17 1998-6-11  ... 1998-6-27
temp_mean9 = temp_mean[1987:2004,:]
temp_deviation9 = temp_deviation[1987:2004,:]

# %%
#MHW18 1998-7-13  ... 1998-10-19
temp_mean10 = temp_mean[2019:2118,:]
temp_deviation10 = temp_deviation[2019:2118,:]

# %%
#MHW19 1998-11-4  ... 1998-11-20
temp_mean11 = temp_mean[2133:2150,:]
temp_deviation11 = temp_deviation[2133:2150,:]

# %%
#MHW20 1998-11-29  ... 1998-12-9
temp_mean12 = temp_mean[2158:2169,:]
temp_deviation12 = temp_deviation[2158:2169,:]

# %%
#MHW21 1998-12-20  ... 1999-2-5
temp_mean13 = temp_mean[2179:2227,:]
temp_deviation13 = temp_deviation[2179:2227,:]

# %%
#MHW22 1999-3-18  ... 1999-3-29
temp_mean14 = temp_mean[2267:2279,:]
temp_deviation14 = temp_deviation[2267:2279,:]

# %%
#MHW23 1999-4-18  ... 1999-4-22
temp_mean15 = temp_mean[2298:2303,:]
temp_deviation15 = temp_deviation[2298:2303,:]

# %%
#MHW24 2000-1-11  ... 2000-1-15
temp_mean16 = temp_mean[2566:2571,:]
temp_deviation16 = temp_deviation[2566:2571,:]

# %%
#MHW25 2000-4-22  ... 2000-5-6
temp_mean17 = temp_mean[2668:2683,:]
temp_deviation17 = temp_deviation[2668:2683,:]

# %%
#MHW26 2001-1-20  ... 2001-1-28
temp_mean18 = temp_mean[2941:2950,:]
temp_deviation18 = temp_deviation[2941:2950,:]

# %%
#MHW27 2001-2-1  ... 2001-2-6
temp_mean19 = temp_mean[2953:2959,:]
temp_deviation19 = temp_deviation[2953:2959,:]

# %%
#MHW28 2001-3-20  ... 2001-3-27
temp_mean20 = temp_mean[3000:3008,:]
temp_deviation20 = temp_deviation[3000:3008,:]

# %%
#MHW29 2001-4-3  ... 2001-4-12
temp_mean21 = temp_mean[3014:3024,:]
temp_deviation21 = temp_deviation[3014:3024,:]

# %%
#MHW30 2001-4-17  ... 2001-4-24
temp_mean22 = temp_mean[3028:3036,:]
temp_deviation22 = temp_deviation[3028:3036,:]

# %%
#MHW31 2001-4-28  ... 2001-5-11
temp_mean23 = temp_mean[3039:3053,:]
temp_deviation23 = temp_deviation[3039:3053,:]

# %%
#MHW32 2001-10-26  ... 2001-10-30
temp_mean24 = temp_mean[3220:3225,:]
temp_deviation24 = temp_deviation[3220:3225,:]

# %%
#MHW33 2001-11-3  ... 2001-11-7
temp_mean25 = temp_mean[3228:3233,:]
temp_deviation25 = temp_deviation[3228:3233,:]

# %%
#MHW34 2002-5-12  ... 2002-5-21
temp_mean26 = temp_mean[3418:3428,:]
temp_deviation26 = temp_deviation[3418:3428,:]

# %%
#MHW35 2002-6-24  ... 2002-7-3
temp_mean27 = temp_mean[3461:3471,:]
temp_deviation27 = temp_deviation[3461:3471,:]

# %%
#MHW36 2002-10-25  ... 2002-11-4
temp_mean28 = temp_mean[3584:3595,:]
temp_deviation28 = temp_deviation[3584:3595,:]

# %%
#MHW37 2002-11-14  ... 2002-11-18
temp_mean29 = temp_mean[3604:3609,:]
temp_deviation29 = temp_deviation[3604:3609,:]

# %%
#MHW38 2002-12-5  ... 2002-12-9
temp_mean30 = temp_mean[3625:3630,:]
temp_deviation30 = temp_deviation[3625:3630,:]

# %%
#MHW39 2002-12-15  ... 2003-1-5
temp_mean31 = temp_mean[3635:3657,:]
temp_deviation31 = temp_deviation[3635:3657,:]

# %%
#MHW40 2005-5-15  ... 2005-5-19
temp_mean32 = temp_mean[4517:4522,:]
temp_deviation32 = temp_deviation[4517:4522,:]

# %%
#MHW41 2005-7-12  ... 2005-7-17
temp_mean33 = temp_mean[4575:4581,:]
temp_deviation33 = temp_deviation[4575:4581,:]

# %%
#MHW42 2005-11-9  ... 2005-11-16
temp_mean34 = temp_mean[4695:4703,:]
temp_deviation34 = temp_deviation[4695:4703,:]

# %%
#MHW43 2006-5-6  ... 2006-5-11
temp_mean35 = temp_mean[4873:4879,:]
temp_deviation35 = temp_deviation[4873:4879,:]

# %%
#MHW44 2006-11-18  ... 2006-12-11
temp_mean36 = temp_mean[5069:5093,:]
temp_deviation36 = temp_deviation[5069:5093,:]

# %%
#MHW45 2007-2-20  ... 2007-2-25
temp_mean37 = temp_mean[5163:5169,:]
temp_deviation37 = temp_deviation[5163:5169,:]

# %%
#MHW46 2007-6-3  ... 2007-6-28
temp_mean38 = temp_mean[5266:5292,:]
temp_deviation38 = temp_deviation[5266:5292,:]

# %%
#MHW47 2007-7-21  ... 2007-8-3
temp_mean39 = temp_mean[5314:5328,:]
temp_deviation39 = temp_deviation[5314:5328,:]

# %%
#MHW48 2008-10-18  ... 2008-11-10
temp_mean40 = temp_mean[5769:5793,:]
temp_deviation40 = temp_deviation[5769:5793,:]

# %%
#MHW49 2009-2-24  ... 2009-2-28
temp_mean41 = temp_mean[5898:5903,:]
temp_deviation41 = temp_deviation[5898:5903,:]

# %%
#MHW50 2009-3-4  ... 2009-3-9
temp_mean42 = temp_mean[5906:5912,:]
temp_deviation42 = temp_deviation[5906:5912,:]

# %%
#MHW51 2009-3-21  ... 2009-3-25
temp_mean43 = temp_mean[5923:5928,:]
temp_deviation43 = temp_deviation[5923:5928,:]

# %%
#MHW52 2010-2-1  ... 2010-2-14
temp_mean44 = temp_mean[6240:6254,:]
temp_deviation44 = temp_deviation[6240:6254,:]

# %%
#MHW53 2010-2-24  ... 2010-3-9
temp_mean45 = temp_mean[6263:6277,:]
temp_deviation45 = temp_deviation[6263:6277,:]

# %%
#MHW54 2010-5-17  ... 2010-6-1
temp_mean46 = temp_mean[6345:6361,:]
temp_deviation46 = temp_deviation[6345:6361,:]

# %%
#MHW55 2010-6-11  ... 2010-7-23
temp_mean47 = temp_mean[6370:6413,:]
temp_deviation47 = temp_deviation[6370:6413,:]

# %%
#MHW56 2010-8-2  ... 2010-8-29
temp_mean48 = temp_mean[6422:6450,:]
temp_deviation48 = temp_deviation[6422:6450,:]

# %%
#MHW57 2010-9-21  ... 2010-10-19
temp_mean49 = temp_mean[6472:6501,:]
temp_deviation49 = temp_deviation[6472:6501,:]

# %%
#MHW58 2012-3-4  ... 2012-3-9
temp_mean50 = temp_mean[7002:7008,:]
temp_deviation50 = temp_deviation[7002:7008,:]

# %%
#MHW59 2012-3-17  ... 2012-3-23
temp_mean51 = temp_mean[7015:7022,:]
temp_deviation51 = temp_deviation[7015:7022,:]

# %%
#MHW60 2012-4-15  ... 2012-5-16
temp_mean52 = temp_mean[7044:7076,:]
temp_deviation52 = temp_deviation[7044:7076,:]

# %%
#MHW61 2012-11-21  ... 2012-12-31
temp_mean53 = temp_mean[7264:7305,:]
temp_deviation53 = temp_deviation[7264:7305,:]

# %%
#MHW62 2013-1-5  ... 2013-1-9
temp_mean54 = temp_mean[7309:7314,:]
temp_deviation54 = temp_deviation[7309:7314,:]

# %%
#MHW63 2013-3-22  ... 2013-4-6
temp_mean55 = temp_mean[7385:7401,:]
temp_deviation55 = temp_deviation[7385:7401,:]

# %%
#MHW64 2013-5-8  ... 2013-6-21
temp_mean56 = temp_mean[7432:7477,:]
temp_deviation56 = temp_deviation[7432:7477,:]

# %%
#MHW65 2013-7-9  ... 2013-7-13
temp_mean57 = temp_mean[7494:7499,:]
temp_deviation57 = temp_deviation[7494:7499,:]

# %%
#MHW66 2014-4-25  ... 2014-5-5
temp_mean58 = temp_mean[7784:7795,:]
temp_deviation58 = temp_deviation[7784:7795,:]

# %%
#MHW67 2014-5-10  ... 2014-6-14
temp_mean59 = temp_mean[7799:7835,:]
temp_deviation59 = temp_deviation[7799:7835,:]

# %%
#MHW68 2014-7-1  ... 2014-7-9
temp_mean60 = temp_mean[7851:7860,:]
temp_deviation60 = temp_deviation[7851:7860,:]

# %%
#MHW69 2014-8-20  ... 2014-8-27
temp_mean61 = temp_mean[7901:7909,:]
temp_deviation61 = temp_deviation[7901:7909,:]

# %%
#MHW70 2014-8-31  ... 2014-9-4
temp_mean62 = temp_mean[7912:7917,:]
temp_deviation62 = temp_deviation[7912:7917,:]

# %%
#MHW71 2014-11-25  ... 2014-12-7
temp_mean63 = temp_mean[7998:8011,:]
temp_deviation63 = temp_deviation[7998:8011,:]

# %%
#MHW72 2015-5-7  ... 2015-6-24
temp_mean64 = temp_mean[8161:8210,:]
temp_deviation64 = temp_deviation[8161:8210,:]

# %%
#MHW73 2015-7-28  ... 2015-8-6
temp_mean65 = temp_mean[8243:8253,:]
temp_deviation65 = temp_deviation[8243:8253,:]

# %%
#MHW74 2015-8-14  ... 2015-8-21
temp_mean66 = temp_mean[8260:8268,:]
temp_deviation66 = temp_deviation[8260:8268,:]

# %%
#MHW75 2015-9-1  ... 2015-10-16
temp_mean67 = temp_mean[8278:8324,:]
temp_deviation67 = temp_deviation[8278:8324,:]

# %%
#MHW76 2015-11-4  ... 2016-1-31
temp_mean68 = temp_mean[8342:8431,:]
temp_deviation68 = temp_deviation[8342:8431,:]

# %%
#MHW77 2016-4-22  ... 2016-7-10
temp_mean69 = temp_mean[8512:8592,:]
temp_deviation69 = temp_deviation[8512:8592,:]

# %%
#MHW78 2016-7-14  ... 2016-8-13
temp_mean70 = temp_mean[8595:8626,:]
temp_deviation70 = temp_deviation[8595:8626,:]

# %%
#MHW79 2016-8-24  ... 2016-9-4
temp_mean71 = temp_mean[8636:8648,:]
temp_deviation71 = temp_deviation[8636:8648,:]

# %%
#MHW80 2016-11-15  ... 2016-12-27
temp_mean72 = temp_mean[8719:8762,:]
temp_deviation72 = temp_deviation[8719:8762,:]

# %%
#MHW81 2017-1-4  ... 2017-1-22
temp_mean73 = temp_mean[8769:8788,:]
temp_deviation73 = temp_deviation[8769:8788,:]

# %%
#MHW82 2017-5-8  ... 2017-5-14
temp_mean74 = temp_mean[8893:8900,:]
temp_deviation74 = temp_deviation[8893:8900,:]

# %%
#MHW83 2017-8-11  ... 2017-8-22
temp_mean75 = temp_mean[8988:9000,:]
temp_deviation75 = temp_deviation[8988:9000,:]

# %%
#MHW84 2017-9-21  ... 2017-10-18
temp_mean76 = temp_mean[9029:9057,:]
temp_deviation76 = temp_deviation[9029:9057,:]

# %%
#MHW85 2017-11-17  ... 2017-12-8
temp_mean77 = temp_mean[9086:9108,:]
temp_deviation77 = temp_deviation[9086:9108,:]

# %%
#MHW86 2018-3-2  ... 2018-3-6
temp_mean78 = temp_mean[9191:9196,:]
temp_deviation78 = temp_deviation[9191:9196,:]

# %%
#MHW87 2018-5-16  ... 2018-6-6
temp_mean79 = temp_mean[9266:9288,:]
temp_deviation79 = temp_deviation[9266:9288,:]

# %%
#MHW88 2018-12-1  ... 2019-1-18
temp_mean80 = temp_mean[9465:9514,:]
temp_deviation80 = temp_deviation[9465:9514,:]

# %%
#MHW89 2019-2-18  ... 2019-2-22
temp_mean81 = temp_mean[9544:9549,:]
temp_deviation81 = temp_deviation[9544:9549,:]

# %%
#MHW90 2019-2-27  ... 2019-3-11
temp_mean82 = temp_mean[9553:9566,:]
temp_deviation82 = temp_deviation[9553:9566,:]

# %%
#MHW91 2019-4-6  ... 2019-5-2
temp_mean83 = temp_mean[9591:9618,:]
temp_deviation83 = temp_deviation[9591:9618,:]

# %%
#MHW92 2019-5-14  ... 2019-6-30
temp_mean84 = temp_mean[9629:9677,:]
temp_deviation84 = temp_deviation[9629:9677,:]

# %%
#MHW93 2019-10-2  ... 2019-10-14
temp_mean85 = temp_mean[9770:9783,:]
temp_deviation85 = temp_deviation[9770:9783,:]

# %%
#MHW94 2019-10-21  ... 2019-11-7
temp_mean86 = temp_mean[9789:9807,:]
temp_deviation86 = temp_deviation[9789:9807,:]

# %%
#MHW95 2020-1-7  ... 2020-1-16
temp_mean87 = temp_mean[9867:9877,:]
temp_deviation87 = temp_deviation[9867:9877,:]

# %%
#MHW96 2020-1-25  ... 2020-1-30
temp_mean88 = temp_mean[9885:9891,:]
temp_deviation88 = temp_deviation[9885:9891,:]

# %%
#MHW97 2020-3-20  ... 2020-4-5
temp_mean89 = temp_mean[9940:9957,:]
temp_deviation89 = temp_deviation[9940:9957,:]

# %%
#MHW98 2020-5-6  ... 2020-10-19
temp_mean90 = temp_mean[9987:10154,:]
temp_deviation90 = temp_deviation[9987:10154,:]

# %%
#MHW99 2020-11-23  ... 2020-11-29
temp_mean91 = temp_mean[10188:10195,:]
temp_deviation91 = temp_deviation[10188:10195,:]

# %%
#MHW100 2020-12-15  ... 2020-12-19
temp_mean92 = temp_mean[10210:10215,:]
temp_deviation92 = temp_deviation[10210:10215,:]

# %%
depth = data1['depth'][:]
depth
# Out:
# array([[   0.],
#        [   5.],
#        [  10.],
#        [  20.],
#        [  30.],
#        [  40.],
#        [  50.],
#        [  60.],
#        [  70.],
#        [  75.],
#        [  80.],
#        [  90.],
#        [ 100.],
#        [ 110.],
#        [ 120.],
#        [ 125.],
#        [ 130.],
#        [ 140.],
#        [ 150.],
#        [ 160.],
#        [ 170.],
#        [ 175.],
#        [ 180.],
#        [ 190.],
#        [ 200.],
#        [ 210.],
#        [ 220.],
#        [ 225.],
#        [ 230.],
#        [ 240.],
#        [ 250.],
#        [ 260.],
#        [ 270.],
#        [ 275.],
#        [ 280.],
#        [ 290.],
#        [ 300.],
#        [ 325.],
#        [ 350.],
#        [ 375.],
#        [ 400.],
#        [ 425.],
#        [ 450.],
#        [ 475.],
#        [ 500.],
#        [ 550.],
#        [ 600.],
#        [ 650.],
#        [ 700.],
#        [ 750.],
#        [ 800.],
#        [ 850.],
#        [ 900.],
#        [ 950.],
# ...

# %%
temp_mean92.shape
# Out:
# (5, 55)

# %%
temp_mean_last1 = np.nanmean(temp_mean65, axis = 0)
temp_deviation_last1 = np.nanmean(temp_deviation92, axis = 0)
temp_mean_last1.shape
# Out:
# (55,)

# %%
temp_mean_last1
# Out:
# array([ 0.57043815,  0.4516475 ,  0.46447737,  0.49504172,  0.55118839,
#         0.47454015,  0.12871971, -0.16253168, -0.35930032, -0.42541957,
#        -0.48149794, -0.55016175, -0.59134241, -0.64582073, -0.59319546,
#        -0.59032362, -0.61141604, -0.51255918, -0.45514361, -0.39445103,
#        -0.32086451, -0.3024917 , -0.3005322 , -0.28311988, -0.22531637,
#        -0.18429753, -0.16981763, -0.15712942, -0.13331027, -0.10242816,
#        -0.0962739 , -0.11629225, -0.12160237, -0.1120705 , -0.10181393,
#        -0.09126033, -0.09008154, -0.09874759, -0.10287413, -0.13643627,
#        -0.10246459, -0.07239925, -0.08787706, -0.07790682, -0.0660739 ,
#        -0.07196709, -0.03225831, -0.03799917, -0.00254997, -0.01388057,
#         0.00345922, -0.0038885 , -0.04566442, -0.04552147, -0.02928737])

# %%
temp_mean.shape
# Out:
# (10227, 55)

# %%
import matplotlib.pyplot as plt
x = temp_mean_last1
y = depth.reshape(-1,)
x2 =temp_deviation_last1 



fig, ax = plt.subplots(dpi= 300)


ax.plot(x, y, label='SSTA', color = '#D62728', linewidth=2.0)
ax.fill_betweenx(y, x-x2, x+x2, alpha=0.3, label='Deviation', color = '#e1edf7')
ax.set_ylim(1000, 0)  
ax.set_xlim(-3, 3)  
ax.set_xlabel('℃')
ax.set_ylabel('pressure(abar)')
ax.axvline(x=0, linestyle='--', color='#A9A9A9')
# ax.legend()
plt.title('SCS 2020/12/15')
plt.text(1, 800, 'D = 5', fontsize=12, color='black')

plt.show()

# %%
Shallow = np.concatenate((temp_mean15,temp_mean16,temp_mean18,temp_mean21,temp_mean41,
                         temp_mean42,temp_mean43,temp_mean50,temp_mean51,temp_mean52,
                         temp_mean55,temp_mean83))
Shallow_deviation = np.concatenate((temp_deviation15,temp_deviation16,temp_deviation18,temp_deviation21,
                                   temp_deviation41,temp_deviation42,temp_deviation43,
                                   temp_deviation50,temp_deviation51,temp_deviation52,temp_deviation55,
                                   temp_deviation83))

# %%
Shallow_mean = np.nanmean(Shallow, axis = 0)
Shallow_deviation_mean = np.nanmean(Shallow_deviation, axis = 0)

# %%
Subsurface_reversed = np.concatenate((temp_mean1,temp_mean2,temp_mean4,temp_mean5,
                                     temp_mean8,temp_mean17,temp_mean22,temp_mean23,temp_mean26,
                                     temp_mean27,temp_mean29,temp_mean30,temp_mean32,temp_mean33,
                                     temp_mean34,temp_mean35,temp_mean36,temp_mean37,temp_mean38,
                                     temp_mean39,temp_mean44,temp_mean45,temp_mean46,temp_mean58,
                                     temp_mean59,temp_mean60,temp_mean61,temp_mean62,temp_mean64,
                                     temp_mean65,temp_mean66,temp_mean67,temp_mean69,temp_mean70,
                                     temp_mean71,temp_mean74,temp_mean78,temp_mean79,temp_mean85,
                                     temp_mean87,temp_mean88,temp_mean89))
Subsurface_reversed_deviation = np.concatenate((temp_deviation1,temp_deviation2,temp_deviation4,
                                               temp_deviation5,temp_deviation8,temp_deviation17,temp_deviation22,temp_deviation23,
                                               temp_deviation26,temp_deviation27,temp_deviation29,temp_deviation30,temp_deviation32,
                                               temp_deviation33,temp_deviation34,temp_deviation35,temp_deviation36,temp_deviation37,
                                               temp_deviation38,temp_deviation39,temp_deviation44,temp_deviation45,temp_deviation46,
                                               temp_deviation58,temp_deviation59,temp_deviation60,temp_deviation61,temp_deviation62,
                                               temp_deviation64,temp_deviation65,temp_deviation66,temp_deviation67,temp_deviation69,
                                               temp_deviation70,temp_deviation71,temp_deviation74,temp_deviation78,temp_deviation79,
                                               temp_deviation85,temp_deviation87,temp_deviation88,temp_deviation89))

# %%
Subsurface_reversed_mean = np.nanmean(Subsurface_reversed, axis = 0)
Subsurface_reversed_deviation_mean = np.nanmean(Subsurface_reversed_deviation, axis = 0)

# %%
Subsurface_intensified = np.concatenate((temp_mean10,temp_mean11,temp_mean12,temp_mean13,
                                        temp_mean14,temp_mean20,temp_mean24,temp_mean25,temp_mean40,
                                        temp_mean47,temp_mean48,temp_mean49,temp_mean53,temp_mean54,
                                        temp_mean56,temp_mean57,temp_mean72,temp_mean73,temp_mean76,
                                        temp_mean77,temp_mean80,temp_mean81,temp_mean82,temp_mean84,
                                        temp_mean90,temp_mean91,temp_mean92))
Subsurface_intensified_deviation = np.concatenate((temp_deviation10,temp_deviation11,temp_deviation12,temp_deviation13,
                                                  temp_deviation14,temp_deviation20,temp_deviation24,temp_deviation25,temp_deviation40,
                                                  temp_deviation47,temp_deviation48,temp_deviation49,temp_deviation53,temp_deviation54,
                                                  temp_deviation56,temp_deviation57,temp_deviation72,temp_deviation73,temp_deviation76,
                                                  temp_deviation77,temp_deviation80,temp_deviation81,temp_deviation82,temp_deviation84,
                                                  temp_deviation90,temp_deviation91,temp_deviation92))

# %%
Subsurface_intensified_mean = np.nanmean(Subsurface_intensified, axis = 0)
Subsurface_intensified_deviation_mean = np.nanmean(Subsurface_intensified_deviation, axis = 0)

# %%
Deep =temp_mean75
Deep_deviation = temp_deviation75

# %%
Deep_mean = np.nanmean(Deep, axis = 0)
Deep_deviation_mean = np.nanmean(Deep_deviation, axis = 0)

# %%
Subsurface_intensified_Reversed = np.concatenate((temp_mean3,temp_mean6,temp_mean7,temp_mean9,temp_mean28,
                                                 temp_mean31,temp_mean63,temp_mean68,temp_mean86
                                                 ))
Subsurface_intensified_Reversed_deviation = np.concatenate((temp_deviation3,temp_deviation6,
                                                           temp_deviation7,temp_deviation9,temp_deviation28,temp_deviation31,
                                                           temp_deviation63,temp_deviation68,temp_deviation86))

# %%
Subsurface_intensified_Reversed_mean = np.nanmean(Subsurface_intensified_Reversed, axis = 0)
Subsurface_intensified_Reversed_deviation_mean = np.nanmean(Subsurface_intensified_Reversed_deviation, axis = 0)

# %%
fig, axes = plt.subplots(1, 5, figsize=(12, 4), dpi=300)

ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]
ax4 = axes[3]
# ax5 = axes[4]
ax6 = axes[4]
y = depth.reshape(-1,)
    
x1 = Shallow_mean    
x11 = Shallow_deviation_mean

x2 = Subsurface_reversed_mean
x22 = Subsurface_reversed_deviation_mean

x3 = Subsurface_intensified_mean
x33 = Subsurface_intensified_deviation_mean

x4 = Deep_mean
x44 = Deep_deviation_mean

x6 = Subsurface_intensified_Reversed_mean
x66 = Subsurface_intensified_Reversed_deviation_mean
    
ax1.plot(x1, y, label='SSTA', color='#D62728', linewidth=2)
ax1.fill_betweenx(y, x1-x11, x1+x11, alpha=0.3, label='Deviation', color='#8fc4dc')
ax1.set_ylim(1000, 0)
ax1.set_xlim(-3, 3)
ax1.set_xlabel('℃')
ax1.set_ylabel('Deep (m)')
ax1.axvline(x=0, linestyle='--', color='#A9A9A9')
ax1.hlines(y=200, xmin=-3, xmax=3, linestyle='--', color='#A9A9A9')
ax1.set_title('Shallow', fontsize=10)
ax1.spines['right'].set_visible(False)

ax2.plot(x2, y,  color='#D62728', linewidth=2)
ax2.fill_betweenx(y, x2-x22, x2+x22, alpha=0.3, label='Deviation', color='#8fc4dc')
ax2.set_ylim(1000, 0)
ax2.set_xlim(-3, 3)
# ax2.set_xlabel('℃', fontsize=9)
ax2.set_ylabel('Deep(m)')
ax2.axvline(x=0, linestyle='--', color='#A9A9A9')
ax2.hlines(y=200, xmin=-3, xmax=3, linestyle='--', color='#A9A9A9')
ax2.set_title('reversed', fontsize=10)
ax2.yaxis.set_ticks_position('none')  
ax2.get_yaxis().set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)
# ax2.set_xticks([])  # 

ax3.plot(x3, y,  color='#D62728', linewidth=2)
ax3.fill_betweenx(y, x3-x33, x3+x33, alpha=0.3, label='Deviation', color='#8fc4dc')
ax3.set_ylim(1000, 0)
ax3.set_xlim(-3, 3)
# ax3.set_xlabel('℃', fontsize=9)
ax3.set_ylabel('Deep(m)')
ax3.axvline(x=0, linestyle='--', color='#A9A9A9')
ax3.hlines(y=200, xmin=-3, xmax=3, linestyle='--', color='#A9A9A9')
ax3.set_title('intensified', fontsize=10)
ax3.yaxis.set_ticks_position('none')  
ax3.get_yaxis().set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.spines['right'].set_visible(False)


ax4.plot(x4, y,  color='#D62728', linewidth=2)
ax4.fill_betweenx(y, x4-x44, x4+x44, alpha=0.3, label='Deviation', color='#8fc4dc')
ax4.set_ylim(1000, 0)
ax4.set_xlim(-3, 3)
# ax3.set_xlabel('℃', fontsize=9)
ax4.set_ylabel('Deep(m)')
ax4.axvline(x=0, linestyle='--', color='#A9A9A9')
ax4.hlines(y=200, xmin=-3, xmax=3, linestyle='--', color='#A9A9A9')
ax4.set_title('Deep', fontsize=10)
ax4.yaxis.set_ticks_position('none')  
ax4.get_yaxis().set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.spines['right'].set_visible(False)


# ax5.plot(x5, y,  color='#D62728', linewidth=2)
# ax5.fill_betweenx(y, x5-x55, x5+x55, alpha=0.3, label='Deviation', color='#e1edf7')
# ax5.set_ylim(1000, 0)
# ax5.set_xlim(-3, 3)
# # ax3.set_xlabel('℃', fontsize=9)
# ax5.set_ylabel('pressure(abar)')
# ax5.axvline(x=0, linestyle='--', color='#A9A9A9')
# ax5.hlines(y=200, xmin=-3, xmax=3, linestyle='--', color='#A9A9A9')
# ax5.set_title('Intensified_reversed', fontsize=10)
# ax5.yaxis.set_ticks_position('none')  # 不显示左右两边的y轴刻度
# ax5.get_yaxis().set_visible(False)
# ax5.spines['left'].set_visible(False)
# ax5.spines['right'].set_visible(False)


ax6.plot(x6, y,  color='#D62728', linewidth=2)
ax6.fill_betweenx(y, x6-x66, x6+x66, alpha=0.3, label='Deviation', color='#8fc4dc')
ax6.set_ylim(1000, 0)
ax6.set_xlim(-3, 3)
# ax3.set_xlabel('℃', fontsize=9)
ax6.set_ylabel('Deep(m)')
ax6.axvline(x=0, linestyle='--', color='#A9A9A9')
ax6.hlines(y=200, xmin=-3, xmax=3, linestyle='--', color='#A9A9A9')
ax6.set_title('intensified_Reversed', fontsize=10)
ax6.yaxis.set_ticks_position('none') 
ax6.get_yaxis().set_visible(False)
ax6.spines['left'].set_visible(False)
# ax6.spines['right'].set_visible(False)

ax1.tick_params(axis='y', direction='in')
ax1.tick_params(axis='x', direction='in')
ax1.tick_params(axis='x', direction='in')
ax2.tick_params(axis='x', direction='in')
ax3.tick_params(axis='x', direction='in')
ax4.tick_params(axis='x', direction='in')
# ax5.tick_params(axis='x', direction='in')
ax6.tick_params(axis='x', direction='in')

ax1.text(0.15,800, 'Num=12',  fontsize=10, color='black')
ax2.text(0.15,800, 'Num=42',  fontsize=10, color='black')
ax3.text(0.15,800, 'Num=28',  fontsize=10, color='black')
ax4.text(0.15,800, 'Num=1',  fontsize=10, color='black')
# ax5.text(0.15,800, 'Nom=13',  fontsize=10, color='black')
ax6.text(0.15,800, 'Num=9',  fontsize=10, color='black')

plt.show()
