# %%
from PIL import Image

# %%
image1 = Image.open('./Tt.png')
image2 = Image.open('./Shallow_Tt.png')
image3 = Image.open('./\Reversed_Tt.png')
image4 = Image.open('./Intensified_Tt.png')
image5 = Image.open('./Deep_Tt.png')
image6 = Image.open('./intensified_Reversed_Tt.png')

# %%
image7 = Image.open('./Sf.png')
image8 = Image.open('./Shallow_Sf.png')
image9 = Image.open('./Reversed_Sf.png')
image10 = Image.open('./Intensified_Sf.png')
image11 = Image.open('./Deep_Sf.png')
image12 = Image.open('./intensified_Reversed_Sf.png')

# %%
image13 = Image.open('./Adv.png')
image14 = Image.open('./Shallow_Adv.png')
image15 = Image.open('./Reversed_Adv.png')
image16 = Image.open('./Intensified_Adv.png')
image17 = Image.open('./\Deep_Adv.png')
image18 = Image.open('./intensified_Reversed_Adv.png')

# %%
image19 = Image.open('./Res.png')
image20 = Image.open('./Shallow_Res.png')
image21 = Image.open('./Reversed_Res.png')
image22 = Image.open('./Intensified_Res.png')
image23 = Image.open('./Deep_Res.png')
image24 = Image.open('./intensified_Reversed_Res.png')

# %%
new_image = Image.new('RGB', (image1.width*6+310 , image1.height*4 + 50), (255, 255, 255))

new_image.paste(image1, (10, 10))
new_image.paste(image2, (image1.width + 20, 10))
new_image.paste(image3, (image1.width*2 + 30, 10))
new_image.paste(image4, (image1.width*3 + 40, 10))
new_image.paste(image5, (image1.width*4 + 50, 10))
new_image.paste(image6, (image1.width*5 + 60, 10))
new_image.paste(image7, (10, image1.height + 20))
new_image.paste(image8, (image1.width + 20, image1.height + 20))
new_image.paste(image9, (image1.width*2 + 30, image1.height + 20))
new_image.paste(image10, (image1.width*3 + 40, image1.height + 20))
new_image.paste(image11, (image1.width*4 + 50, image1.height + 20))
new_image.paste(image12, (image1.width*5 + 50, image1.height + 20))

new_image.paste(image13, (10, image1.height*2 + 30))
new_image.paste(image14, (image1.width + 20, image1.height*2 + 30))
new_image.paste(image15, (image1.width*2 + 30, image1.height*2 + 30))
new_image.paste(image16, (image1.width*3 + 40, image1.height*2 + 30))
new_image.paste(image17, (image1.width*4 + 50, image1.height*2 + 30))
new_image.paste(image18, (image1.width*5 + 60, image1.height*2 + 30))
new_image.paste(image19, (10, image1.height*3 + 40))
new_image.paste(image20, (image1.width + 20, image1.height*3 + 40))
new_image.paste(image21, (image1.width*2 + 30, image1.height*3 + 40))
new_image.paste(image22, (image1.width*3 + 40, image1.height*3 + 40))
new_image.paste(image23, (image1.width*4 + 50, image1.height*3 + 40))
new_image.paste(image24, (image1.width*5 + 60, image1.height*3 + 40))

new_image.save('./merged_image1.png')

# %%
import numpy as np
import os
import pandas as pd
import glob
from netCDF4 import Dataset, num2date
import netCDF4 as nc
import time
import datetime

path = r'./dt_global_allsat_phy_l4_20130301_20210726.nc'
nc0 = Dataset(path)

# %%
nc0.variables
# Out:
# {'crs': <class 'netCDF4._netCDF4.Variable'>
#  int32 crs()
#      comment: This is a container variable that describes the grid_mapping used by the data in this file. This variable does not contain any data; only information about the geographic coordinate system.
#      grid_mapping_name: latitude_longitude
#      inverse_flattening: 298.257
#      semi_major_axis: 6378136.3
#  unlimited dimensions:
#  current shape = ()
#  filling on, default _FillValue of -2147483647 used,
#  'time': <class 'netCDF4._netCDF4.Variable'>
#  float32 time(time)
#      axis: T
#      calendar: gregorian
#      long_name: Time
#      standard_name: time
#      units: days since 1950-01-01 00:00:00
#  unlimited dimensions:
#  current shape = (1,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'latitude': <class 'netCDF4._netCDF4.Variable'>
#  float32 latitude(latitude)
#      axis: Y
#      bounds: lat_bnds
#      long_name: Latitude
#      standard_name: latitude
# ...
